# %%
from endstate_rew.analysis import (save_mol_pic, 
                                   get_traj, 
                                   get_indices, 
                                   vis_torsions)

# %%
vis_torsions(zinc_id=1, ff='charmmff', switching=True, switching_length=5)
# Out:
# ################################## SYSTEM ZINC00077329 ##################################
# 3 rotatable bonds found.
# ---------- Investigating bond nr 0 ----------
# No heavy atom torsions found for bond 0
# []
# No dihedrals will be computed for bond nr 0
# ---------- Investigating bond nr 1 ----------
# [[3, 4, 6, 7]]
# Dihedrals are computed for bond nr 1
# ---------- Investigating bond nr 2 ----------
# No heavy atom torsions found for bond 2
# []
# No dihedrals will be computed for bond nr 2
